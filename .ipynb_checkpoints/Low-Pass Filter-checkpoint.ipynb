# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal, fftpack
# %matplotlib inline

# %%
# Number of samplepoints
N = 800
# sample spacing
T = 1.0 / N

x = np.linspace(0.0, N*T, N)

# %%
def plot_fft(y):
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
    plt.plot(xf, 2.0/N * np.abs(yf[:N//2]))

# %%
def plot(y):
    x = np.linspace(0.0, N*T, N)
    plt.plot(x, y)

# %%
def plot_both(y):
    fig, axes = plt.subplots(2, figsize=(12, 8))
    
    x = np.linspace(0.0, N*T, N)
    axes[0].plot(x, y)
    
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
    axes[1].plot(xf, 2.0/N * np.abs(yf[:N//2]))

# %%
def low_pass_filter(y):
    return y[2:] + y[:-2]

# %%
x = np.linspace(0.0, N*T, N)
y = signal.sawtooth(10.0 * 2.0*np.pi*x)
plot_both(y)

# %%
x = np.linspace(0.0, (N+2)*T, N+2)
y = low_pass_filter(signal.sawtooth(20.0 * 2.0*np.pi*x))
plot_both(y)

# %%
def max_amplitude(freq):
    x = np.linspace(0.0, (N+1)*T, N+1)
    y = np.exp(freq*2.0*np.pi*1j*x)
    return np.absolute(low_pass_filter(y)).max()

def angle(freq):
    x = np.linspace(0.0, (N+1)*T, N+1)
    y = np.exp(freq*2.0*np.pi*1j*x)
    return np.mean(np.angle(y[:-1]*np.conj(low_pass_filter(y))))/(2.0*np.pi)

freqs = range(1, 400)
ampout = [max_amplitude(f) for f in freqs]
angles = [angle(f) for f in freqs]
fig, axes = plt.subplots(2, figsize=(12, 8))
axes[0].plot(freqs, ampout)
axes[1].plot(freqs, angles)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-166adbf49adc> in <module>()
#      11 freqs = range(1, 400)
#      12 ampout = [max_amplitude(f) for f in freqs]
# ---> 13 angles = [angle(f) for f in freqs]
#      14 fig, axes = plt.subplots(2, figsize=(12, 8))
#      15 axes[0].plot(freqs, ampout)
#
# <ipython-input-9-166adbf49adc> in angle(freq)
#       7     x = np.linspace(0.0, (N+1)*T, N+1)
#       8     y = np.exp(freq*2.0*np.pi*1j*x)
# ----> 9     return np.mean(np.angle(y[:-1]*np.conj(low_pass_filter(y))))/(2.0*np.pi)
#      10
#      11 freqs = range(1, 400)
#
# ValueError: operands could not be broadcast together with shapes (800,) (799,)
